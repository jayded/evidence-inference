# %% [markdown]
# ### Evidence Inference
#
# This task involves consuming two inputs: (1) a natural language (full-text) article describing a clinical trial, and, (2) an "evidence prompt" that specifies an intervention, comparator and outcome of interest. For example, the trial may have been comparing over-the-counter headache medicine, and the "prompt" may read:
#
# With respect to frequency of contractions, characterize the difference between antibiotics and placebo.
#
# > With respect to *duration of headache* (outcome), characterize the difference between *aspirin* (intervention) and *placebo* (comparator)
#
# The task is then to infer the reported finding for this triplet. In particular, this is framed as a classification task with three categories: *significantly decreased*, *no significant difference*.

# %%
import random

# %%
import numpy as np
import pandas as pd
import torch

# %%
import preprocessor
# Out:
# <module 'preprocessor' from '/Users/byron/dev/evidence-inference/preprocessor.py'>

# %%
PROMPT_ID_COL_NAME = "RowID"

# %%
prompts = pd.read_csv("pilot_run_data/prompts.csv")
annotations = pd.read_csv("pilot_run_data/annotations.csv")

# %%
prompts.head()
# Out:
#    RowID               Outcome         Intervention            Comparator  \
# 0      1  venous ulcer healing    two-layer bandage  compression stocking
# 1      2  venous ulcer healing   four-layer bandage  compression stocking
# 2      3  venous ulcer healing  compression therapy          no treatment
# 3      4  venous ulcer healing   four-layer bandage     two-layer bandage
# 4      5           CEAP scores   four-layer bandage     two-layer bandage
#
#                       Answer  \
# 0  no significant difference
# 1  no significant difference
# 2    significantly increased
# 3  no significant difference
# 4  no significant difference
#
#                                            Reasoning      XML  Answer_Vals
# 0  However, the observed differences were not sta...  3298351            0
# 1  However, the observed differences were not sta...  3298351            0
# 2  We compared the dynamics of ulcer healing of p...  3298351            1
# 3  What is more, no statistically significant adv...  3298351            0
# 4  The statistical analysis did not reveal any st...  3298351            0

# %%
annotations.head()
# Out:
#    UserId  RowID    PMCID                  Selection  \
# 0       0   82.0  2875419    Significantly increased
# 1       0   75.0  3281242    Significantly increased
# 2       0   64.0  1764008  No significant difference
# 3       0   79.0  2875419  No significant difference
# 4       0   13.0  2366143  No significant difference
#
#                                           Annotation  \
# 0  Weight gain was higher for glargine (differenc...
# 1  Continuous abstinence was higher for varenicli...
# 2  Differences in the duration of the active-firs...
# 3  The proportions of patients achieving A1C <7% ...
# 4  No significant differences in the interval to ...
#
#                                          Outcome  \
# 0                                   Weight Gain
# 1   continuous abstienence at 24 week follow up
# 2                      duration of labor stages
# 3               number of patients with A1C <7%
# 4                             neonatal outcomes
#
#                            Comparator            Intervention  Invalid Prompt  \
# 0                            detemir                glargine                0
# 1                            placebo             varenicline                0
# 2                 epidural analgesia    Meperidine analgesia                0
# 3                          glargine                 detemir                 0
# 4   antibiotic therapy and tocolysis               tocolysis                0
#
#   Prompt Reason  Answer_Val  In Abstract
# 0           NaN           1            1
# 1           NaN           1            1
# 2           NaN           0            1
# 3           NaN           0            0
# 4           NaN           0            1

# %% [markdown]
# Create a temporary validation set for experimentation. ***TODO*** once we collect a reasonable amount of data we will have official train/val/test splits.

# %%
unique_articles = annotations["PMCID"].unique()
train_set_size = int(0.8 * len(unique_articles))
train_doc_ids = np.random.choice(unique_articles, train_set_size, replace=False)
val_doc_ids = [doc_id for doc_id in unique_articles if not doc_id in train_doc_ids]

# %%
inference_vectorizer = preprocessor.get_inference_vectorizer(article_ids=train_doc_ids)

# %%
training_prompts = prompts[prompts['XML'].isin(train_doc_ids)]

# filter out prompts for which we do not have annotations for whatever reason
# this was actually just one case; not sure what was going on there.
def have_annotations_for_prompt(prompt_id):
    return len(annotations[annotations[PROMPT_ID_COL_NAME] == prompt_id]) > 0

training_prompts = [prompt for row_idx, prompt in training_prompts.iterrows() if 
                        have_annotations_for_prompt(prompt[PROMPT_ID_COL_NAME])]

training_prompts = pd.DataFrame(training_prompts)

# %%
type(training_prompts)
# Out:
# pandas.core.frame.DataFrame

# %%
train_Xy = []
for prompt_id in training_prompts[PROMPT_ID_COL_NAME].values:
    Xy_dict = inference_vectorizer.vectorize(training_prompts, prompt_id, include_lbls=True, annotations_df=annotations)
    train_Xy.append(Xy_dict)

# %%
train_Xy[0]
# Out:
# {'C': [240, 855],
#  'I': [385, 481, 168],
#  'O': [825, 805, 411],
#  'article': [782,
#   234,
#   563,
#   769,
#   324,
#   563,
#   240,
#   737,
#   137,
#   481,
#   240,
#   760,
#   437,
#   825,
#   806,
#   795,
#   94,
#   94,
#   470,
#   769,
#   121,
#   563,
#   769,
#   680,
#   829,
#   783,
#   232,
#   769,
#   317,
#   563,
#   825,
#   805,
#   411,
#   835,
#   794,
#   841,
#   769,
#   816,
#   563,
#   240,
#   737,
#   158,
#   833,
#   158,
#   573,
#   803,
#   137,
#   385,
#   481,
#   168,
#   760,
#   94,
#   504,
#   137,
#   519,
#   400,
#   563,
#   58,
#   590,
#   748,
#   388,
#   825,
#   807,
#   829,
#   739,
#   776,
#   400,
#   252,
#   563,
#   47,
#   78,
#   846,
#   137,
#   5,
#   30,
#   76,
#   515,
#   119,
#   178,
#   54,
#   137,
#   83,
#   850,
#   769,
#   166,
#   118,
#   829,
#   72,
#   850,
#   137,
#   769,
#   511,
#   829,
#   73,
#   590,
#   834,
#   645,
#   468,
#   779,
#   401,
#   383,
#   795,
#   841,
#   769,
#   629,
#   803,
#   481,
#   758,
#   627,
#   385,
#   481,
#   240,
#   137,
#   841,
#   769,
#   816,
#   563,
#   240,
#   737,
#   220,
#   430,
#   437,
#   769,
#   200,
#   563,
#   534,
#   481,
#   240,
#   240,
#   337,
#   53,
#   527,
#   182,
#   617,
#   163,
#   139,
#   484,
#   829,
#   817,
#   94,
#   684,
#   437,
#   124,
#   590,
#   444,
#   563,
#   769,
#   804,
#   563,
#   240,
#   771,
#   368,
#   712,
#   734,
#   213,
#   563,
#   806,
#   154,
#   437,
#   781,
#   834,
#   558,
#   738,
#   766,
#   383,
#   503,
#   583,
#   3,
#   769,
#   479,
#   492,
#   563,
#   806,
#   154,
#   437,
#   319,
#   563,
#   769,
#   747,
#   509,
#   829,
#   558,
#   437,
#   590,
#   794,
#   841,
#   769,
#   385,
#   481,
#   758,
#   565,
#   166,
#   70,
#   226,
#   591,
#   831,
#   769,
#   721,
#   492,
#   563,
#   806,
#   154,
#   829,
#   558,
#   437,
#   590,
#   818,
#   240,
#   737,
#   565,
#   166,
#   56,
#   225,
#   94,
#   244,
#   759,
#   240,
#   771,
#   150,
#   841,
#   612,
#   182,
#   617,
#   563,
#   53,
#   527,
#   471,
#   133,
#   323,
#   518,
#   563,
#   251,
#   795,
#   563,
#   825,
#   807,
#   240,
#   737,
#   137,
#   613,
#   760,
#   563,
#   534,
#   481,
#   240,
#   834,
#   215,
#   190,
#   715,
#   223,
#   324],
#  'y': array([['No significant difference',
#          'In all patients, independently of the type of compression therapy, a few significant statistical changes of ulceration area in time were observed (Student’s t test for matched pairs, p < 0.05). The largest loss of ulceration area in each of the successive measurements was observed in patients treated with the four-layer system – on average 0.63 cm2/per week. The smallest loss of ulceration area was observed in patients using compression stockings – on average 0.44 cm2/per week. However, the observed differences were not statistically significant (Kruskal-Wallis test H = 4.45, p > 0.05).'],
#         ['Significantly increased',
#          'The largest loss of ulceration area in each of the successive measurements was observed in patients treated with the four-layer system – on average 0.63 cm2/per week. The smallest loss of ulceration area was observed in patients using compression stockings – on average 0.44 cm2/per week.'],
#         ['No significant difference',
#          'In all patients, independently of the type of compression therapy, a few significant statistical changes of ulceration area in time were observed (Student’s t test for matched pairs, p < 0.05). The largest loss of ulceration area in each of the successive measurements was observed in patients treated with the four-layer system – on average 0.63 cm2/per week. The smallest loss of ulceration area was observed in patients using compression stockings – on average 0.44 cm2/per week. However, the observed differences were not statistically significant (Kruskal-Wallis test H = 4.45, p > 0.05).']], dtype=object)}

# %%
val_prompts = prompts[~prompts['XML'].isin(train_doc_ids)]
val_Xy = []
for prompt_id in val_prompts[PROMPT_ID_COL_NAME].values:
    Xy_dict = inference_vectorizer.vectorize(val_prompts, prompt_id, include_lbls=True, annotations_df=annotations)
    val_Xy.append(Xy_dict)

# %%
val_Xy[0]
# Out:
# {'C': [855, 855, 563, 803, 855, 855],
#  'I': [802, 855, 716, 855, 855],
#  'O': [855],
#  'article': [782,
#   855,
#   563,
#   855,
#   855,
#   437,
#   855,
#   855,
#   137,
#   367,
#   577,
#   94,
#   94,
#   167,
#   769,
#   264,
#   855,
#   263,
#   855,
#   855,
#   855,
#   855,
#   315,
#   855,
#   855,
#   257,
#   776,
#   741,
#   829,
#   855,
#   783,
#   232,
#   769,
#   326,
#   563,
#   263,
#   855,
#   803,
#   295,
#   855,
#   855,
#   855,
#   855,
#   565,
#   855,
#   855,
#   137,
#   855,
#   578,
#   437,
#   855,
#   611,
#   846,
#   94,
#   519,
#   803,
#   425,
#   137,
#   855,
#   846,
#   841,
#   717,
#   855,
#   550,
#   855,
#   304,
#   137,
#   855,
#   855,
#   7,
#   855,
#   834,
#   646,
#   161,
#   783,
#   566,
#   563,
#   779,
#   401,
#   855,
#   400,
#   855,
#   803,
#   855,
#   855,
#   855,
#   855,
#   855,
#   6,
#   521,
#   855,
#   591,
#   831,
#   76,
#   400,
#   855,
#   566,
#   855,
#   802,
#   855,
#   6,
#   521,
#   855,
#   591,
#   831,
#   76,
#   137,
#   400,
#   855,
#   566,
#   855,
#   263,
#   62,
#   521,
#   855,
#   591,
#   267,
#   76,
#   550,
#   107,
#   855,
#   834,
#   855,
#   855,
#   137,
#   855,
#   855,
#   855,
#   834,
#   508,
#   163,
#   27,
#   40,
#   137,
#   50,
#   832,
#   855,
#   137,
#   855,
#   578,
#   855,
#   765,
#   518,
#   563,
#   276,
#   855,
#   855,
#   736,
#   834,
#   136,
#   94,
#   684,
#   437,
#   788,
#   855,
#   846,
#   236,
#   769,
#   635,
#   772,
#   829,
#   712,
#   293,
#   437,
#   855,
#   855,
#   137,
#   855,
#   855,
#   437,
#   400,
#   163,
#   50,
#   832,
#   94,
#   243,
#   802,
#   855,
#   855,
#   471,
#   158,
#   323,
#   158,
#   263,
#   855,
#   137,
#   506,
#   855,
#   133,
#   95,
#   855,
#   437,
#   855,
#   855,
#   664,
#   383,
#   855,
#   611,
#   846],
#  'y': array([['No significant difference',
#          'No significant difference was observed with respect to pregnancy or birth outcome across the groups.'],
#         ['No significant difference',
#          'the twice-weekly regime has shown equal effectiveness as a daily supplementation regimen with respect to maintaining safe hemoglobin and ferritin levels throughout pregnancy.'],
#         ['No significant difference',
#          'No significant difference was observed with respect to pregnancy or birth outcome across the groups']], dtype=object)}
